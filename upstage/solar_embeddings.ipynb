# %% [markdown]
# <a href="https://colab.research.google.com/github/ychoi-kr/LLM-API/blob/main/solar_embeddings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 솔라 임베딩 API

# %%
# !pip install openai
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.30.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.7.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai) (4.11.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.18.2)

# %%
from google.colab import userdata
import os

api_key = userdata.get('UPSTAGE_API_KEY')

# %%
from openai import OpenAI
client = OpenAI(
    api_key=api_key,
    base_url="https://api.upstage.ai/v1/solar"
)

# %% [markdown]
# ## 임베딩

# %%
response = client.embeddings.create(
    input="왕",
    model="solar-embedding-1-large-passage"
)

print(response.data[0].embedding)
# Out:
# [0.0102386474609375, 0.005893707275390625, -0.0134735107421875, 0.0223388671875, -0.006168365478515625, -0.0030460357666015625, -0.016510009765625, -0.01409912109375, 0.0032958984375, -0.0008378028869628906, 0.0103759765625, 0.01184844970703125, -0.00788116455078125, -0.022064208984375, 0.0016984939575195312, 0.020172119140625, -0.0196685791015625, 0.01030731201171875, 0.00798797607421875, -0.0192718505859375, -0.01294708251953125, 0.00860595703125, -0.00777435302734375, 0.0139312744140625, -0.0031070709228515625, -0.0041046142578125, 0.0086669921875, 0.0038852691650390625, 0.012786865234375, 0.00812530517578125, 0.0138702392578125, -0.00823974609375, 0.00960540771484375, -0.0112152099609375, -0.007717132568359375, -0.0078582763671875, -0.01251983642578125, 0.006229400634765625, -0.008514404296875, -0.0080413818359375, 0.0142364501953125, 0.00820159912109375, -0.0267181396484375, -0.002376556396484375, -0.01194000244140625, -0.0135498046875, -0.0008206367492675781, -0.0127716064453125, -0.0017194747924804688, 0.00836944580078125, 0.00701141357421875, -0.026763916015625, -0.010650634765625, -0.036285400390625, -0.0286407470703125, 0.004825592041015625, -0.022369384765625, -0.012908935546875, 0.017120361328125, 0.00467681884765625, -0.0230865478515625, -0.012420654296875, 0.02093505859375, -0.01189422607421875, 0.00997161865234375, -0.0281219482421875, 0.0013036727905273438, 0.0059661865234375, -0.006542205810546875, 0.0156707763671875, 0.0017786026000976562, 0.0196075439453125, 0.0159454345703125, 0.0299072265625, -0.035858154296875, -0.002002716064453125, 0.000782012939453125, -0.02020263671875, 0.0010728836059570312, 0.020416259765625, 0.006103515625, 0.02423095703125, -0.0185394287109375, 0.0188140869140625, -0.038604736328125, 0.02398681640625, -0.0082244873046875, 0.0037136077880859375, 0.003040313720703125, -0.005268096923828125, 0.002803802490234375, -0.047882080078125, 0.01004791259765625, 0.0184783935546875, -0.0231475830078125, 0.0145111083984375, -0.0168304443359375, 0.0035858154296875, 0.0234375, -9.888410568237305e-05, 0.022369384765625, 0.009552001953125, -0.01141357421875, -0.01467132568359375, 0.0066070556640625, -0.00916290283203125, 0.003368377685546875, -0.012664794921875, 0.00652313232421875, 0.0168304443359375, 0.01445770263671875, -0.0146484375, -0.01308441162109375, -0.0195465087890625, -0.0281829833984375, -0.01358795166015625, 0.0120697021484375, 0.007038116455078125, 0.010467529296875, -0.0016603469848632812, 0.00960540771484375, 0.034698486328125, -0.01299285888671875, 0.0034198760986328125, 0.002063751220703125, -0.0287017822265625, 0.0018339157104492188, 0.0125274658203125, 0.0123291015625, -0.0055999755859375, 0.0219573974609375, 0.01103973388671875, 0.0161590576171875, 0.019256591796875, 0.0037288665771484375, 0.00308990478515625, 0.00991058349609375, -0.002758026123046875, 0.0013866424560546875, 0.025604248046875, -0.01103973388671875, 0.00550079345703125, 0.01116180419921875, -0.013275146484375, 0.00597381591796875, 0.005157470703125, 0.0086822509765625, 0.0028514862060546875, -0.007274627685546875, 0.0158233642578125, -0.03497314453125, 0.00152587890625, -0.01045989990234375, -0.0094757080078125, 0.0301513671875, 0.00319671630859375, -0.01047515869140625, 0.0201416015625, 0.013763427734375, -0.019134521484375, 0.0020580291748046875, -0.01236724853515625, -0.00855255126953125, -0.00567626953125, -0.0037364959716796875, 0.0219268798828125, 0.034912109375, -0.0150299072265625, -0.01407623291015625, -0.00429534912109375, 0.005443572998046875, 0.0185546875, -0.016265869140625, 0.01399993896484375, -0.00921630859375, 0.011199951171875, 0.007171630859375, -0.0015039443969726562, 0.0002002716064453125, -0.00799560546875, -0.0091400146484375, -0.01155853271484375, -0.006832122802734375, 0.021575927734375, 0.005153656005859375, -0.0055694580078125, 0.0002617835998535156, 0.0037708282470703125, -0.004032135009765625, 0.01081085205078125, -0.01294708251953125, -0.01515960693359375, -0.032470703125, -0.0012 ...

# %%
def embedding_passage(input):
    response = client.embeddings.create(
        input=input,
        model="solar-embedding-1-large-passage"
    )

    return response.data[0].embedding

def embedding_query(input):
    response = client.embeddings.create(
        input=input,
        model="solar-embedding-1-large-query"
    )

    return response.data[0].embedding

# %% [markdown]
# ## 코사인 유사도

# %%
import numpy as np

def cosine_similarity(a, b):
    return np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b))

# %%
import pandas as pd

proverbs = [
    "가는 말이 고와야 오는 말이 곱다",
    "가는 날이 장날이다",
    "개구리 올챙이 적 생각 못 한다",
    "고래 싸움에 새우 등 터진다",
    "공든 탑이 무너지랴",
    "구슬이 서 말이라도 꿰어야 보배",
    "그림의 떡",
    "김칫국부터 마신다",
    "낫 놓고 기역 자도 모른다",
    "누워서 떡 먹기",
    "등잔 밑이 어둡다",
    "뛰는 놈 위에 나는 놈 있다",
    "말 한마디로 천 냥 빚 갚는다",
    "매도 먼저 맞는 게 낫다",
    "모로 가도 서울만 가면 된다",
    "물이 깊을수록 소리가 없다",
    "바늘 도둑이 소 도둑 된다",
    "배보다 배꼽이 크다",
    "백지장도 맞들면 낫다",
    "보기 좋은 떡이 먹기도 좋다",
    "콩 심은 데 콩 나고 팥 심은 데 팥 난다",
    "티끌 모아 태산",
    "시작이 반이다"
]

df = pd.DataFrame({'속담': proverbs})
df['embedding'] = df['속담'].apply(embedding_passage)
df
# Out:
#                          속담                                          embedding
# 0        가는 말이 고와야 오는 말이 곱다  [-0.00739288330078125, 0.009613037109375, -0.0...
# 1                가는 날이 장날이다  [-0.006801605224609375, -0.00921630859375, -0....
# 2         개구리 올챙이 적 생각 못 한다  [-0.00926971435546875, 0.0004954338073730469, ...
# 3           고래 싸움에 새우 등 터진다  [0.0036220550537109375, -0.0070648193359375, -...
# 4                공든 탑이 무너지랴  [-0.01824951171875, -0.017059326171875, -0.017...
# 5         구슬이 서 말이라도 꿰어야 보배  [-0.0124053955078125, 0.0128173828125, -0.0065...
# 6                     그림의 떡  [0.0017900466918945312, 0.0024890899658203125,...
# 7                 김칫국부터 마신다  [-0.0004630088806152344, -0.01076507568359375,...
# 8            낫 놓고 기역 자도 모른다  [0.01189422607421875, 0.0016918182373046875, 0...
# 9                  누워서 떡 먹기  [-0.006122589111328125, -0.0021457672119140625...
# 10                등잔 밑이 어둡다  [-0.0100250244140625, -0.00185394287109375, 0....
# 11          뛰는 놈 위에 나는 놈 있다  [0.0003631114959716797, -0.00197601318359375, ...
# 12         말 한마디로 천 냥 빚 갚는다  [-0.00618743896484375, 0.00878143310546875, 0....
# 13            매도 먼저 맞는 게 낫다  [-0.01380157470703125, 0.003704071044921875, 0...
# 14          모로 가도 서울만 가면 된다  [-0.0211944580078125, -0.0003752708435058594, ...
# 15           물이 깊을수록 소리가 없다  [-0.00917816162109375, 0.01422119140625, 0.003...
# 16           바늘 도둑이 소 도둑 된다  [-0.002910614013671875, -0.01047515869140625, ...
# 17               배보다 배꼽이 크다  [0.0152587890625, -0.01018524169921875, -0.005...
# 18              백지장도 맞들면 낫다  [-0.026611328125, 0.01503753662109375, -0.0183...
# 19          보기 좋은 떡이 먹기도 좋다  [-0.0095062255859375, 0.01593017578125, -0.005...
# 20  콩 심은 데 콩 나고 팥 심은 데 팥 난다  [-0.010040283203125, -0.007045745849609375, -0...
# 21                 티끌 모아 태산  [0.005214691162109375, 0.0127716064453125, -0....
# 22                  시작이 반이다  [0.00650787353515625, 0.0211029052734375, -0.0...

# %%
# df의 각 단어에 대해 질의문과 코사인 유사도를 계산하고 내림차순 정렬

df['cosine_similarity'] = df['embedding'].apply(
    lambda x: cosine_similarity(x, embedding_query('아니 땐 굴뚝에 연기 나랴?'))
)
df.sort_values(by='cosine_similarity', ascending=False)
# Out:
#                          속담  \
# 4                공든 탑이 무너지랴
# 20  콩 심은 데 콩 나고 팥 심은 데 팥 난다
# 1                가는 날이 장날이다
# 18              백지장도 맞들면 낫다
# 16           바늘 도둑이 소 도둑 된다
# 14          모로 가도 서울만 가면 된다
# 3           고래 싸움에 새우 등 터진다
# 11          뛰는 놈 위에 나는 놈 있다
# 13            매도 먼저 맞는 게 낫다
# 2         개구리 올챙이 적 생각 못 한다
# 5         구슬이 서 말이라도 꿰어야 보배
# 10                등잔 밑이 어둡다
# 0        가는 말이 고와야 오는 말이 곱다
# 8            낫 놓고 기역 자도 모른다
# 21                 티끌 모아 태산
# 7                 김칫국부터 마신다
# 12         말 한마디로 천 냥 빚 갚는다
# 22                  시작이 반이다
# 15           물이 깊을수록 소리가 없다
# 19          보기 좋은 떡이 먹기도 좋다
# 17               배보다 배꼽이 크다
# 6                     그림의 떡
# 9                  누워서 떡 먹기
#
#                                             embedding  cosine_similarity
# 4   [-0.01824951171875, -0.017059326171875, -0.017...           0.248281
# 20  [-0.010040283203125, -0.007045745849609375, -0...           0.233744
# 1   [-0.006801605224609375, -0.00921630859375, -0....           0.213224
# 18  [-0.026611328125, 0.01503753662109375, -0.0183...           0.207951
# 16  [-0.002910614013671875, -0.01047515869140625, ...           0.203440
# 14  [-0.0211944580078125, -0.0003752708435058594, ...           0.202889
# 3   [0.0036220550537109375, -0.0070648193359375, -...           0.188418
# 11  [0.0003631114959716797, -0.00197601318359375, ...           0.187549
# 13  [-0.01380157470703125, 0.003704071044921875, 0...           0.184172
# 2   [-0.00926971435546875, 0.0004954338073730469, ...           0.183821
# 5   [-0.0124053955078125, 0.0128173828125, -0.0065...           0.180964
# 10  [-0.0100250244140625, -0.00185394287109375, 0....           0.177175
# 0   [-0.00739288330078125, 0.009613037109375, -0.0...           0.176198
# 8   [0.01189422607421875, 0.0016918182373046875, 0...           0.167916
# 21  [0.005214691162109375, 0.0127716064453125, -0....           0.167715
# 7   [-0.0004630088806152344, -0.01076507568359375,...           0.164839
# 12  [-0.00618743896484375, 0.00878143310546875, 0....           0.163784
# 22  [0.00650787353515625, 0.0211029052734375, -0.0...           0.158555
# 15  [-0.00917816162109375, 0.01422119140625, 0.003...           0.156627
# 19  [-0.0095062255859375, 0.01593017578125, -0.005...           0.156524
# 17  [0.0152587890625, -0.01018524169921875, -0.005...           0.149697
# 6   [0.0017900466918945312, 0.0024890899658203125,...           0.133361
# 9   [-0.006122589111328125, -0.0021457672119140625...           0.108502

# %%
df['cosine_similarity'] = df['embedding'].apply(
    lambda x: cosine_similarity(x, embedding_query('천 리 길도 한 걸음부터'))
)
df.sort_values(by='cosine_similarity', ascending=False)
# Out:
#                          속담  \
# 22                  시작이 반이다
# 12         말 한마디로 천 냥 빚 갚는다
# 21                 티끌 모아 태산
# 14          모로 가도 서울만 가면 된다
# 5         구슬이 서 말이라도 꿰어야 보배
# 16           바늘 도둑이 소 도둑 된다
# 18              백지장도 맞들면 낫다
# 1                가는 날이 장날이다
# 13            매도 먼저 맞는 게 낫다
# 7                 김칫국부터 마신다
# 4                공든 탑이 무너지랴
# 0        가는 말이 고와야 오는 말이 곱다
# 2         개구리 올챙이 적 생각 못 한다
# 19          보기 좋은 떡이 먹기도 좋다
# 11          뛰는 놈 위에 나는 놈 있다
# 8            낫 놓고 기역 자도 모른다
# 20  콩 심은 데 콩 나고 팥 심은 데 팥 난다
# 9                  누워서 떡 먹기
# 17               배보다 배꼽이 크다
# 10                등잔 밑이 어둡다
# 6                     그림의 떡
# 3           고래 싸움에 새우 등 터진다
# 15           물이 깊을수록 소리가 없다
#
#                                             embedding  cosine_similarity
# 22  [0.00650787353515625, 0.0211029052734375, -0.0...           0.251237
# 12  [-0.00618743896484375, 0.00878143310546875, 0....           0.243213
# 21  [0.005214691162109375, 0.0127716064453125, -0....           0.222208
# 14  [-0.0211944580078125, -0.0003752708435058594, ...           0.214886
# 5   [-0.0124053955078125, 0.0128173828125, -0.0065...           0.196937
# 16  [-0.002910614013671875, -0.01047515869140625, ...           0.174723
# 18  [-0.026611328125, 0.01503753662109375, -0.0183...           0.174441
# 1   [-0.006801605224609375, -0.00921630859375, -0....           0.171586
# 13  [-0.01380157470703125, 0.003704071044921875, 0...           0.170184
# 7   [-0.0004630088806152344, -0.01076507568359375,...           0.168761
# 4   [-0.01824951171875, -0.017059326171875, -0.017...           0.165460
# 0   [-0.00739288330078125, 0.009613037109375, -0.0...           0.165399
# 2   [-0.00926971435546875, 0.0004954338073730469, ...           0.148561
# 19  [-0.0095062255859375, 0.01593017578125, -0.005...           0.147291
# 11  [0.0003631114959716797, -0.00197601318359375, ...           0.140277
# 8   [0.01189422607421875, 0.0016918182373046875, 0...           0.139007
# 20  [-0.010040283203125, -0.007045745849609375, -0...           0.135819
# 9   [-0.006122589111328125, -0.0021457672119140625...           0.128307
# 17  [0.0152587890625, -0.01018524169921875, -0.005...           0.122438
# 10  [-0.0100250244140625, -0.00185394287109375, 0....           0.122421
# 6   [0.0017900466918945312, 0.0024890899658203125,...           0.114283
# 3   [0.0036220550537109375, -0.0070648193359375, -...           0.109861
# 15  [-0.00917816162109375, 0.01422119140625, 0.003...           0.104829

# %%
df['cosine_similarity'] = df['embedding'].apply(
    lambda x: cosine_similarity(x, embedding_query('이왕이면 다홍 치마'))
)
df.sort_values(by='cosine_similarity', ascending=False)
# Out:
#                          속담  \
# 19          보기 좋은 떡이 먹기도 좋다
# 13            매도 먼저 맞는 게 낫다
# 0        가는 말이 고와야 오는 말이 곱다
# 17               배보다 배꼽이 크다
# 14          모로 가도 서울만 가면 된다
# 1                가는 날이 장날이다
# 5         구슬이 서 말이라도 꿰어야 보배
# 12         말 한마디로 천 냥 빚 갚는다
# 7                 김칫국부터 마신다
# 18              백지장도 맞들면 낫다
# 3           고래 싸움에 새우 등 터진다
# 22                  시작이 반이다
# 20  콩 심은 데 콩 나고 팥 심은 데 팥 난다
# 2         개구리 올챙이 적 생각 못 한다
# 6                     그림의 떡
# 16           바늘 도둑이 소 도둑 된다
# 11          뛰는 놈 위에 나는 놈 있다
# 10                등잔 밑이 어둡다
# 4                공든 탑이 무너지랴
# 21                 티끌 모아 태산
# 9                  누워서 떡 먹기
# 8            낫 놓고 기역 자도 모른다
# 15           물이 깊을수록 소리가 없다
#
#                                             embedding  cosine_similarity
# 19  [-0.0095062255859375, 0.01593017578125, -0.005...           0.223439
# 13  [-0.01380157470703125, 0.003704071044921875, 0...           0.206585
# 0   [-0.00739288330078125, 0.009613037109375, -0.0...           0.193449
# 17  [0.0152587890625, -0.01018524169921875, -0.005...           0.186029
# 14  [-0.0211944580078125, -0.0003752708435058594, ...           0.181494
# 1   [-0.006801605224609375, -0.00921630859375, -0....           0.178873
# 5   [-0.0124053955078125, 0.0128173828125, -0.0065...           0.163007
# 12  [-0.00618743896484375, 0.00878143310546875, 0....           0.160735
# 7   [-0.0004630088806152344, -0.01076507568359375,...           0.160438
# 18  [-0.026611328125, 0.01503753662109375, -0.0183...           0.157129
# 3   [0.0036220550537109375, -0.0070648193359375, -...           0.156166
# 22  [0.00650787353515625, 0.0211029052734375, -0.0...           0.147000
# 20  [-0.010040283203125, -0.007045745849609375, -0...           0.144942
# 2   [-0.00926971435546875, 0.0004954338073730469, ...           0.144310
# 6   [0.0017900466918945312, 0.0024890899658203125,...           0.137382
# 16  [-0.002910614013671875, -0.01047515869140625, ...           0.129995
# 11  [0.0003631114959716797, -0.00197601318359375, ...           0.122579
# 10  [-0.0100250244140625, -0.00185394287109375, 0....           0.110332
# 4   [-0.01824951171875, -0.017059326171875, -0.017...           0.108323
# 21  [0.005214691162109375, 0.0127716064453125, -0....           0.099072
# 9   [-0.006122589111328125, -0.0021457672119140625...           0.098394
# 8   [0.01189422607421875, 0.0016918182373046875, 0...           0.078448
# 15  [-0.00917816162109375, 0.01422119140625, 0.003...           0.048594
