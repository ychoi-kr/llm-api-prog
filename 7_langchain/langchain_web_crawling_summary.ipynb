# %%
# !pip install langchain-core==0.2.41 langchain==0.2.16 langchain-openai==0.1.23 langchain-upstage==0.2.2 selenium unstructured
# Out:
# Requirement already satisfied: langchain-core==0.2.41 in c:\users\yong\appdata\local\programs\python\python312\lib\site-packages (0.2.41)
# Requirement already satisfied: langchain==0.2.16 in c:\users\yong\appdata\roaming\python\python312\site-packages (0.2.16)
# Requirement already satisfied: langchain-openai==0.1.23 in c:\users\yong\appdata\roaming\python\python312\site-packages (0.1.23)
# Requirement already satisfied: langchain-upstage==0.2.2 in c:\users\yong\appdata\roaming\python\python312\site-packages (0.2.2)
# Collecting selenium
#   Downloading selenium-4.25.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting unstructured
#   Downloading unstructured-0.15.14-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\yong\appdata\roaming\python\python312\site-packages (from langchain-core==0.2.41) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\yong\appdata\roaming\python\python312\site-packages (from langchain-core==0.2.41) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.112 in c:\users\yong\appdata\roaming\python\python312\site-packages (from langchain-core==0.2.41) (0.1.135)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\yong\appdata\roaming\python\python312\site-packages (from langchain-core==0.2.41) (24.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\yong\appdata\local\programs\python\python312\lib\site-packages (from langchain-core==0.2.41) (2.9.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\yong\appdata\roaming\python\python312\site-packages (from langchain-core==0.2.41) (8.5.0)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\yong\appdata\roaming\python\python312\site-packages (from langchain-core==0.2.41) (4.12.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\yong\appdata\roaming\python\python312\site-packages (from langchain==0.2.16) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\yong\appdata\roaming\python\python312\site-packages (from langchain==0.2.16) (3.10.10)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\yong\appdata\roaming\python\python312\site-packages (from langchain==0.2.16) (0.2.4)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\yong\appdata\roaming\python\python312\site-packages (from langchain==0.2.16) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in c:\users\yong\appdata\roaming\python\python312\site-packages (from langchain==0.2.16) (2.32.3)
# Requirement already satisfied: openai<2.0.0,>=1.40.0 in c:\users\yong\appdata\roaming\python\python312\site-packages (from langchain-openai==0.1.23) (1.51.2)
# Requirement already satisfied: tiktoken<1,>=0.7 in c:\users\yong\appdata\roaming\python\python312\site-packages (from langchain-openai==0.1.23) (0.8.0)
# Requirement already satisfied: pypdf<5.0.0,>=4.2.0 in c:\users\yong\appdata\roaming\python\python312\site-packages (from langchain-upstage==0.2.2) (4.3.1)
# Requirement already satisfied: tokenizers<0.20.0,>=0.19.1 in c:\users\yong\appdata\roaming\python\python312\site-packages (from langchain-upstage==0.2.2) (0.19.1)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\yong\appdata\roaming\python\python312\site-packages (from urllib3[socks]<3,>=1.26->selenium) (2.2.3)
# Collecting trio~=0.17 (from selenium)
#   Downloading trio-0.27.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting trio-websocket~=0.9 (from selenium)
#   Downloading trio_websocket-0.11.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\yong\appdata\roaming\python\python312\site-packages (from selenium) (2024.8.30)
# Requirement already satisfied: websocket-client~=1.8 in c:\users\yong\appdata\local\programs\python\python312\lib\site-packages (from selenium) (1.8.0)
# Collecting chardet (from unstructured)
#   Downloading chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting filetype (from unstructured)
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting python-magic (from unstructured)
#   Using cached python_magic-0.4.27-py2.py3-none-any.whl.metadata (5.8 kB)
# Collecting lxml (from unstructured)
#   Downloading lxml-5.3.0-cp312-cp312-win_amd64.whl.metadata (3.9 kB)
# Collecting nltk (from unstructured)
#   Downloading nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting tabulate (from unstructured)
#   Using cached tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: beautifulsoup4 in c:\users\yong\appdata\roaming\python\python312\site-packages (from unstructured) (4.12.3)
# Collecting emoji (from unstructured)
#   Downloading emoji-2.14.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: dataclasses-json in c:\users\yong\appdata\local\programs\python\python312\lib\site-packages (from unstructured) (0.6.7)
# Collecting python-iso639 (from unstructured)
#   Using cached python_iso639-2024.4.27-py3-none-any.whl.metadata (13 kB)
# Collecting langdetect (from unstructured)
#   Using cached langdetect-1.0.9.tar.gz (981 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting rapidfuzz (from unstructured)
#   Downloading rapidfuzz-3.10.0-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting backoff (from unstructured)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting unstructured-client (from unstructured)
#   Downloading unstructured_client-0.26.1-py3-none-any.whl.metadata (20 kB)
# Collecting wrapt (from unstructured)
#   Downloading wrapt-1.16.0-cp312-cp312-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: tqdm in c:\users\yong\appdata\roaming\python\python312\site-packages (from unstructured) (4.66.5)
# Requirement already satisfied: psutil in c:\users\yong\appdata\local\programs\python\python312\lib\site-packages (from unstructured) (6.0.0)
# Collecting python-oxmsg (from unstructured)
#   Downloading python_oxmsg-0.0.1-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\yong\appdata\roaming\python\python312\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.16) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\yong\appdata\roaming\python\python312\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.16) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\yong\appdata\roaming\python\python312\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.16) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\yong\appdata\roaming\python\python312\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.16) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\yong\appdata\roaming\python\python312\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.16) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\users\yong\appdata\roaming\python\python312\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.16) (1.15.4)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\yong\appdata\roaming\python\python312\site-packages (from jsonpatch<2.0,>=1.33->langchain-core==0.2.41) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\yong\appdata\roaming\python\python312\site-packages (from langsmith<0.2.0,>=0.1.112->langchain-core==0.2.41) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\yong\appdata\roaming\python\python312\site-packages (from langsmith<0.2.0,>=0.1.112->langchain-core==0.2.41) (3.10.7)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\yong\appdata\roaming\python\python312\site-packages (from langsmith<0.2.0,>=0.1.112->langchain-core==0.2.41) (1.0.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\yong\appdata\roaming\python\python312\site-packages (from openai<2.0.0,>=1.40.0->langchain-openai==0.1.23) (4.6.2.post1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\yong\appdata\roaming\python\python312\site-packages (from openai<2.0.0,>=1.40.0->langchain-openai==0.1.23) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\yong\appdata\roaming\python\python312\site-packages (from openai<2.0.0,>=1.40.0->langchain-openai==0.1.23) (0.6.1)
# Requirement already satisfied: sniffio in c:\users\yong\appdata\roaming\python\python312\site-packages (from openai<2.0.0,>=1.40.0->langchain-openai==0.1.23) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\yong\appdata\roaming\python\python312\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core==0.2.41) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\yong\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core==0.2.41) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\yong\appdata\roaming\python\python312\site-packages (from requests<3,>=2->langchain==0.2.16) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yong\appdata\roaming\python\python312\site-packages (from requests<3,>=2->langchain==0.2.16) (3.10)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\yong\appdata\roaming\python\python312\site-packages (from SQLAlchemy<3,>=1.4->langchain==0.2.16) (3.1.1)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\yong\appdata\roaming\python\python312\site-packages (from tiktoken<1,>=0.7->langchain-openai==0.1.23) (2024.9.11)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\yong\appdata\roaming\python\python312\site-packages (from tokenizers<0.20.0,>=0.19.1->langchain-upstage==0.2.2) (0.25.2)
# Requirement already satisfied: colorama in c:\users\yong\appdata\roaming\python\python312\site-packages (from tqdm->unstructured) (0.4.6)
# Collecting sortedcontainers (from trio~=0.17->selenium)
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting outcome (from trio~=0.17->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: cffi>=1.14 in c:\users\yong\appdata\local\programs\python\python312\lib\site-packages (from trio~=0.17->selenium) (1.17.1)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting pysocks!=1.5.7,<2.0,>=1.5.6 (from urllib3[socks]<3,>=1.26->selenium)
#   Downloading PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: soupsieve>1.2 in c:\users\yong\appdata\roaming\python\python312\site-packages (from beautifulsoup4->unstructured) (2.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\yong\appdata\local\programs\python\python312\lib\site-packages (from dataclasses-json->unstructured) (3.22.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\yong\appdata\local\programs\python\python312\lib\site-packages (from dataclasses-json->unstructured) (0.9.0)
# Requirement already satisfied: six in c:\users\yong\appdata\local\programs\python\python312\lib\site-packages (from langdetect->unstructured) (1.16.0)
# Collecting click (from nltk->unstructured)
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting joblib (from nltk->unstructured)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting olefile (from python-oxmsg->unstructured)
#   Downloading olefile-0.47-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting cryptography>=3.1 (from unstructured-client->unstructured)
#   Downloading cryptography-43.0.1-cp39-abi3-win_amd64.whl.metadata (5.4 kB)
# Collecting eval-type-backport<0.3.0,>=0.2.0 (from unstructured-client->unstructured)
#   Downloading eval_type_backport-0.2.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting jsonpath-python<2.0.0,>=1.0.6 (from unstructured-client->unstructured)
#   Using cached jsonpath_python-1.0.6-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: nest-asyncio>=1.6.0 in c:\users\yong\appdata\local\programs\python\python312\lib\site-packages (from unstructured-client->unstructured) (1.6.0)
# Collecting python-dateutil==2.8.2 (from unstructured-client->unstructured)
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: pycparser in c:\users\yong\appdata\local\programs\python\python312\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.22)
# Requirement already satisfied: httpcore==1.* in c:\users\yong\appdata\roaming\python\python312\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-core==0.2.41) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\yong\appdata\roaming\python\python312\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-core==0.2.41) (0.14.0)
# Requirement already satisfied: filelock in c:\users\yong\appdata\roaming\python\python312\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<0.20.0,>=0.19.1->langchain-upstage==0.2.2) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\yong\appdata\roaming\python\python312\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<0.20.0,>=0.19.1->langchain-upstage==0.2.2) (2024.9.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\yong\appdata\local\programs\python\python312\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured) (1.0.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\yong\appdata\roaming\python\python312\site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain==0.2.16) (0.2.0)
# Downloading selenium-4.25.0-py3-none-any.whl (9.7 MB)
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ------------------------------ --------- 7.3/9.7 MB 37.6 MB/s eta 0:00:01
#    ---------------------------------------- 9.7/9.7 MB 35.5 MB/s eta 0:00:00
# Downloading unstructured-0.15.14-py3-none-any.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 39.3 MB/s eta 0:00:00
# Downloading trio-0.27.0-py3-none-any.whl (481 kB)
# Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
# Downloading emoji-2.14.0-py3-none-any.whl (586 kB)
#    ---------------------------------------- 0.0/586.9 kB ? eta -:--:--
#    --------------------------------------- 586.9/586.9 kB 21.7 MB/s eta 0:00:00
# Using cached filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading lxml-5.3.0-cp312-cp312-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 3.8/3.8 MB 38.2 MB/s eta 0:00:00
# Downloading nltk-3.9.1-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 40.1 MB/s eta 0:00:00
# Using cached python_iso639-2024.4.27-py3-none-any.whl (274 kB)
# Using cached python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Downloading python_oxmsg-0.0.1-py3-none-any.whl (31 kB)
# Downloading rapidfuzz-3.10.0-cp312-cp312-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 1.6/1.6 MB 28.6 MB/s eta 0:00:00
# Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Downloading unstructured_client-0.26.1-py3-none-any.whl (60 kB)
# Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# Downloading wrapt-1.16.0-cp312-cp312-win_amd64.whl (37 kB)
# Downloading cryptography-43.0.1-cp39-abi3-win_amd64.whl (3.1 MB)
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    ---------------------------------------- 3.1/3.1 MB 36.0 MB/s eta 0:00:00
# Downloading eval_type_backport-0.2.0-py3-none-any.whl (5.9 kB)
# Using cached jsonpath_python-1.0.6-py3-none-any.whl (7.6 kB)
# Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Downloading click-8.1.7-py3-none-any.whl (97 kB)
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading olefile-0.47-py2.py3-none-any.whl (114 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py): started
#   Building wheel for langdetect (setup.py): finished with status 'done'
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993251 sha256=9cdc662641e8c6634450685c8799a4680a0c85c9a84a7e5940f496d437ca1805
#   Stored in directory: c:\users\yong\appdata\local\pip\cache\wheels\c1\67\88\e844b5b022812e15a52e4eaa38a1e709e99f06f6639d7e3ba7
# Successfully built langdetect
# Installing collected packages: sortedcontainers, filetype, wsproto, wrapt, tabulate, rapidfuzz, python-magic, python-iso639, python-dateutil, pysocks, outcome, olefile, lxml, langdetect, jsonpath-python, joblib, eval-type-backport, emoji, click, chardet, backoff, trio, python-oxmsg, nltk, cryptography, unstructured-client, trio-websocket, unstructured, selenium
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.9.0.post0
#     Uninstalling python-dateutil-2.9.0.post0:
#       Successfully uninstalled python-dateutil-2.9.0.post0
# Successfully installed backoff-2.2.1 chardet-5.2.0 click-8.1.7 cryptography-43.0.1 emoji-2.14.0 eval-type-backport-0.2.0 filetype-1.2.0 joblib-1.4.2 jsonpath-python-1.0.6 langdetect-1.0.9 lxml-5.3.0 nltk-3.9.1 olefile-0.47 outcome-1.3.0.post0 pysocks-1.7.1 python-dateutil-2.8.2 python-iso639-2024.4.27 python-magic-0.4.27 python-oxmsg-0.0.1 rapidfuzz-3.10.0 selenium-4.25.0 sortedcontainers-2.4.0 tabulate-0.9.0 trio-0.27.0 trio-websocket-0.11.1 unstructured-0.15.14 unstructured-client-0.26.1 wrapt-1.16.0 wsproto-1.2.0

# %%
from langchain_community.document_loaders import SeleniumURLLoader
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

from langchain_upstage import ChatUpstage
#from langchain_openai import ChatOpenAI

# %%
urls = """
https://wikibook.co.kr/vector-search/
https://wikibook.co.kr/llm-apps/
https://wikibook.co.kr/copilot/
https://wikibook.co.kr/my-chatgpt/
https://wikibook.co.kr/langchain/
""".strip().split("\n")

# %%
loader = SeleniumURLLoader(urls)
docs = loader.load()

# %%
prompt = ChatPromptTemplate.from_messages(
    [("system", "Write a concise summary of the following in Korean:\n\n{context}")]
)
output_parser = StrOutputParser()

model = ChatUpstage()
#model = ChatOpenAI()

chain = (
    prompt
    | model
    | output_parser
)

# %%
for doc in docs:
    print(f"URL: {doc.metadata['source']}")
    print(f"Title: {doc.metadata['title']}")
    summary = chain.invoke({"context": doc.page_content})
    print(f"Summary: {summary}\n\n")
# Out:
# URL: https://wikibook.co.kr/vector-search/
# Title: 엘라스틱서치를 활용한 벡터 검색 실무 가이드 | 위키북스
# Summary: 이 책은 "엘라스틱을 활용한 벡터 검색 실무 가이드: 자연어 처리와 생성형 AI, RAG를 위한 대규모 벡터 데이터베이스"라는 제목을 가지고 있습니다. 이 책은 자연어 처리와 생성형 AI, RAG를 위한 대규모 벡터 데이터베이스를 구축하는 데 필요한 엘라스틱을 활용한 벡터 검색과 가시성, 사이버 보안, 챗GPT와의 통합을 최적화하는 방법을 가르쳐줍니다. 이 책은 먼저 NLP와 NLP 프로세스에서 엘라스틱의 기능을 소개합니다. 그런 다음, 벡터 검색과 엘라스틱을 통합하여 검색 사례뿐만 아니라 가시성과 사이버 보안 기능을 개선하는 데 중점을 둔 장으로 이어집니다. 이 책에는 엘라스틱을 사용하여 벡터 검색을 구현하고 최적화하는 데 필요한 모든 기술이 포함되어 있습니다. 이 책에서는 벡터 검색 기능을 사용하여 성능을 최적화하고, 이미지 벡터 검색과 그 적용 분야를 탐구하며, 개인 식별 정보를 탐지하고 마스킹하고, 차세대 가시성을 위한 로그 분석 및 검색을 구현하고, 사이버 보안을 위한 벡터 기반 봇 탐지를 사용하고, 벡터 공간을 시각화하고 엘라스틱의 최신 검색 기능을 살펴보고, Streamlit을 사용하여 RAG 강화 애플리케이션을 구현하는 방법에 대해 다룹니다.
#
#
# URL: https://wikibook.co.kr/llm-apps/
# Title: 챗GPT와 랭체인을 활용한 LLM 기반 AI 앱 개발 | 위키북스
# Summary: 이 책은 챗GPT와 Langchain 프레임워크를 사용하여 대규모 언어 모델(LLM)을 사용하여 애플리케이션에 통합하는 방법을 가르치는 책입니다. LLM 애플리케이션 개발의 모든 단계, 즉 OpenAI API 및 Langchain의 기본 개념부터 웹 애플리케이션 및 Slack 앱 구축, 그리고 프로덕션 배포에 이르기까지 단계별 실습을 통해 학습할 수 있습니다. 또한, 벡터 데이터베이스, 서버리스 아키텍처 등의 최신 기술을 활용하는 방법과 보안 및 개인 정보 보호에 대한 노하우도 배울 수 있습니다. 이 책을 통해 LLM의 잠재력을 현실로 구현할 수 있는 개발자가 될 수 있습니다.
#
#
# URL: https://wikibook.co.kr/copilot/
# Title: AI 코딩 어시스턴트 깃허브 코파일럿 제대로 활용하기 | 위키북스
# Summary: 위키북스 출판사에서는 GitHub Copilot, ChatGPT와 같은 AI 코드 어시스턴트를 사용하여 효율적으로 코딩하는 방법을 안내하는 "AI 코딩 어시스턴트 GitHub Copilot 제대로 활용하기"라는 책을 소개하고 있습니다. 이 책은 AI를 사용하여 Python 프로그램을 작성하고 개선하는 방법을 보여주며, 컴퓨터 프로그램 작성 방식을 근본적으로 변화시키고 있습니다. 이 책은 AI 어시스턴트를 사용하여 아이디어를 빠르게 구현하는 방법을 안내하며, AI 어시스턴트가 생성하는 내용을 이해하고 개선할 수 있을 만큼 Python 언어를 배울 수 있습니다. 이 책은 컴퓨터에서 파일을 이동하고 새로운 프로그램을 설치할 수 있는 모든 사람들에게 유용한 소프트웨어 작성법을 배우고자 하는 사람들에게 적합합니다.
#
#
# URL: https://wikibook.co.kr/my-chatgpt/
# Title: OpenAI API와 파이썬으로 나만의 챗GPT 만들기 | 위키북스
# Summary: 위키북스의 "OpenAI API와 파이썬으로 챗GPT 만들기"라는 책은 OpenAI API를 사용하여 파이썬으로 챗봇과 같은 AI 애플리케이션을 개발하는 방법을 가르쳐줍니다. 이 책은 챗GPT와 API의 기본 개념부터 시작하여, 챗봇, 음성 인식 및 요약과 같은 실제 예제를 통해 OpenAI API의 다양한 사용법을 학습할 수 있습니다. 또한, LangChain과 Chroma를 사용하여 대화형 애플리케이션 개발을 간소화하는 방법도 소개합니다. 이 책을 통해 독자들은 AI 애플리케이션을 직접 만들 수 있는 능력을 갖출 수 있습니다.
#
#
# URL: https://wikibook.co.kr/langchain/
# Title: 랭체인 완벽 입문 | 위키북스
# Summary: '랭체인 완벽 입문'은 랭체인을 사용하여 생성형 AI 앱을 개발하는 방법을 다루는 책입니다. 이 책은 랭체인의 각 모듈을 사용하여 AI 앱을 개발하는 방법을 가르치며, 다양한 실제 예제 코드를 제공합니다. 이 책은 파이썬과 비주얼 스튜디오 코드(VS Code)를 사용하여 여러 플랫폼에서 개발하는 방법을 익히고, AI와 대화하는 방법을 배우는 프롬프트 엔지니어링의 기초를 다룹니다. 이 책은 초보자를 대상으로 하며, 생성형 AI 앱을 개발하고자 하는 사람들에게 필수적인 내용을 다룹니다.
