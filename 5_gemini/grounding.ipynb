# %%
# !pip install google-generativeai==0.8.4

# %%
from google.colab import userdata
import google.generativeai as genai
import os

genai.configure(api_key= "AIzaSyApl3rWK9aliuucmWg2yoUvTmax7smW8pA")
model = genai.GenerativeModel('gemini-1.5-flash-002')

response = model.generate_content(contents="현재 비트코인 가격을 출력한 후 상승할지 하락할지 예측하고, 그 근거를 20 단어 이내로 설명하세요.",  tools='google_search_retrieval')
print(response.text)
# Out:
# 현재 비트코인 가격은 여러 소스에 따라 다르게 제시되고 있으며, 9만 3천 달러에서 9만 4천 달러 사이입니다.  상승할 가능성이 높습니다.  3월은 과거 데이터상 비트코인 가격 강세 시기이며,  ETF 승인 및 계절적 요인이 상승을 뒷받침할 것으로 예상됩니다.

# %%
print(response.candidates[0].grounding_metadata.grounding_chunks)
# Out:
# [web {
#   uri: "https://vertexaisearch.cloud.google.com/grounding-api-redirect/AQXblrzopvOAuq4Nh7UjhTQxK4G7oHGJRuVuKXyRZP6jXx_vufICJJbZWSfD1LbQA0BS2HlWAv3_PwiVcENFHxxHwGYWEHqHQ69gptJM48hAzu1uM6i7CvnlbqwkTtEL0gtHML6H-E1DbQ=="
#   title: "tradingview.com"
# }
# , web {
#   uri: "https://vertexaisearch.cloud.google.com/grounding-api-redirect/AQXblrzSLB1HfEOvR0W5_GWlq-u9JHjGXbM7SHJIwJJXa81yikk2Zm8udbLsEN4uf9l5VY5SXtcMlbw8BasgeKHFyqF8p3TGcGE0wpOJsBPb36pQxgbF_-Lt8VxPqOfiqlgfC2gkjDNNlIpK1mPTCudkjzdNfvMu-NUC2O56UJGc"
#   title: "businesspost.co.kr"
# }
# ]

# %%
model = genai.GenerativeModel('gemini-1.5-flash-002')
response = model.generate_content(contents="현재 비트코인 가격을 출력한 후 상승할지 하락할지 예측하고, 그 근거를 20 단어 이내로 설명하세요.",   tools={"google_search_retrieval": {"dynamic_retrieval_config": {"mode": "MODE_DYNAMIC", "dynamic_threshold": 0.9}}})

print(response.text)
print(response.candidates[0].grounding_metadata.retrieval_metadata)
# Out:
# 현재 비트코인 가격은 실시간으로 변동하므로 제공할 수 없습니다.  예측은 불가능하며 투자 조언이 아닙니다.  시장 심리와 규제 변화가 가격에 영향을 미칩니다.
#
# google_search_dynamic_retrieval_score: 0.713513851
